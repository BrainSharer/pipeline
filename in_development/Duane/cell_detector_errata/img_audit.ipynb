# %%
#28-JUN-2025

import os
from pathlib import Path
import cv2
import matplotlib.pyplot as plt
import numpy as np
from compress_pickle import dump, load

img_path = Path('/', 'scratch', 'pipeline_tmp', 'CTB015', 'cell_candidates')
img_file = Path(img_path, 'diff3_000.gz')

img_data = load(img_file)
print('ch3 difference image shape:', img_data.shape)

fig, ax = plt.subplots(figsize=(10, 10))  # Adjust this to your screen
ax.imshow(img_data, cmap='gray' if img_data.ndim == 2 else None)
ax.axis('off')
plt.show()
# Out:
# ch3 difference image shape: (35264, 64768)
