# %%
from pathlib import Path
import imageio.v2 as imageio
import numpy as np
import matplotlib.pyplot as plt
from compress_pickle import dump, load

animal = 'DK41'
section = 240
filename = f'extracted_cells_{section}.gz'
src = Path('/', 'scratch', 'pipeline_tmp', animal, 'cell_candidates', filename)

print(f'LOADING FROM {src}')
cell_candidates = load(src)
print(f'TOTAL CELL CANDIDATES: {len(cell_candidates)}')
# Out:
# LOADING FROM /scratch/pipeline_tmp/DK41/cell_candidates/extracted_cells_240.gz
# TOTAL CELL CANDIDATES: 9594

# %%
''' created with cell_utilities.py::filter_cell_candidates:
cell = {
    "animal": animal,
    "section": section_number,
    "area": object_area,
    "absolute_coordinates_YX": (
        absolute_coordinates[2] + segment_col,
        absolute_coordinates[0] + segment_row,
    ),
    "cell_shape_XY": (height, width),
    "image_CH3": difference_ch3[row_start:row_end, col_start:col_end].T,
    "image_CH1": difference_ch1[row_start:row_end, col_start:col_end].T,
    "mask": segment_mask.T,
}      
'''
# img_all = len(cell_candidates)
img_all = cell_candidates[5192]#['image_CH1'].shape
img_all
# Out:
# {'animal': 'DK41',
#  'section': 240,
#  'area': 982,
#  'absolute_coordinates_YX': (18013, 31446),
#  'cell_shape_XY': (50, 44),
#  'image_CH3': Array([[-86.5246 , -86.5246 , -86.5246 , ..., 168.02704, -88.97296,
#          -88.97296],
#         [-86.5246 , -86.5246 , -86.5246 , ..., -88.97296, -88.97296,
#          168.02704],
#         [-86.5246 , -86.5246 , -86.5246 , ..., 168.02704, 168.02704,
#          168.02704],
#         ...,
#         [-74.3241 , -74.3241 , -74.3241 , ..., -73.47186, -73.47186,
#          -73.47186],
#         [-74.3241 , -74.3241 , -74.3241 , ..., -73.47186, -73.47186,
#          -73.47186],
#         [-74.3241 , -74.3241 , -74.3241 , ..., -73.47186, -73.47186,
#          -73.47186]], dtype=float32),
#  'image_CH1': Array([[-2796.6738  , -2796.6738  , -4844.674   , ..., -1175.2344  ,
#          -1175.2344  ,   872.7656  ],
#         [-2796.6738  , -4844.674   , -2796.6738  , ...,   872.7656  ,
#            872.7656  ,   872.7656  ],
#         [-2796.6738  , -2796.6738  , -2796.6738  , ...,   872.7656  ,
#            872.7656  ,   872.7656  ],
#         ...,
#         [-1498.9766  , -1498.9766  ,   549.02344 , ..., -1990.7998  ,
#             57.200195, -1990.7998  ],
#         [-1498.9766  , -1498.9766  , -1498.9766  , ..., -1990.7998  ,
#          -1990.7998  , -1990.7998  ],
#         [-1498.9766  , -1498.9766  , -1498.9766  , ..., -1990.7998  ,
#          -1990.7998  , -1990.7998  ]], dtype=float32),
#  'mask': array([[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]])}

# %%
img = img_all['image_CH3']
plt.imshow(img, cmap='viridis')
plt.show()

# %%
img = img_all['image_CH1']
plt.imshow(img, cmap='viridis')
plt.show()

# %%
img = img_all['mask']
plt.imshow(img, cmap='viridis')
plt.show()
