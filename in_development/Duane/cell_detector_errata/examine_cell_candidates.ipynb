# %%
from pathlib import Path
import imageio.v2 as imageio
import numpy as np
import matplotlib.pyplot as plt
from compress_pickle import dump, load

animal = 'CTB015'
filename = 'extracted_cells_061.gz'
src = Path('/', 'scratch', 'pipeline_tmp', animal, 'cell_candidates', filename)

print(f'LOADING FROM {src}')
cell_candidates = load(src)
print(f'TOTAL CELL CANDIDATES: {len(cell_candidates)}')
# Out:
# LOADING FROM /scratch/pipeline_tmp/CTB015/cell_candidates/extracted_cells_061.gz

# %%
img_all = cell_candidates[109433]
img_all
# Out:
# {'animal': 'CTB015',
#  'section': 61,
#  'area': 4,
#  'absolute_coordinates_YX': (51801, 18500),
#  'cell_shape_XY': (3, 2),
#  'image_CH3': Array([[  151.35107 ,   116.351074,   -25.648926, ...,   673.58984 ,
#            733.58984 ,   486.58984 ],
#         [   40.351074,   -70.648926,   117.351074, ...,   770.58984 ,
#            606.58984 ,   474.58984 ],
#         [  -17.648926,   -44.648926,   237.35107 , ...,   335.58984 ,
#            534.58984 ,   286.58984 ],
#         ...,
#         [  774.6787  ,    12.678711,   -29.32129 , ..., -1029.4102  ,
#          -1068.4102  ,  -932.41016 ],
#         [  457.6787  ,   -55.32129 ,    36.67871 , ...,  -804.41016 ,
#           -878.41016 ,  -778.41016 ],
#         [  517.6787  ,   150.67871 ,    -7.321289, ...,  -697.41016 ,
#           -792.41016 ,  -499.41016 ]], dtype=float32),
#  'image_CH1': Array([[ 1739.9814 ,   702.98145,  -235.01855, ...,  4057.919  ,
#           3884.919  ,  5892.919  ],
#         [ 2451.9814 ,  1134.9814 ,   901.98145, ...,  4110.919  ,
#           4316.919  ,  5786.919  ],
#         [ 3182.9814 ,  1067.9814 ,  -169.01855, ...,  4150.919  ,
#           5068.919  ,  6298.919  ],
#         ...,
#         [-3200.1719 , -3386.1719 , -3067.1719 , ...,  -821.77344,
#           -854.77344,  -382.77344],
#         [-3532.1719 , -2894.1719 , -3213.1719 , ..., -1480.7734 ,
#           -509.77344,  -555.77344],
#         [-3805.1719 , -2907.1719 , -3479.1719 , ...,  -841.77344,
#           -901.77344, -1100.7734 ]], dtype=float32),
#  'mask': array([[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]])}

# %%
img = img_all['image_CH3']
plt.imshow(img, cmap='viridis')
plt.show()

# %%
img = img_all['image_CH1']
plt.imshow(img, cmap='viridis')
plt.show()

# %%
img = img_all['mask']
plt.imshow(img, cmap='viridis')
plt.show()
