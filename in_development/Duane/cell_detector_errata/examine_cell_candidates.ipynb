# %%
from pathlib import Path
import imageio.v2 as imageio
import numpy as np
import matplotlib.pyplot as plt
from compress_pickle import dump, load

animal = 'CTB015'
filename = 'extracted_cells_061.gz'
src = Path('/', 'scratch', 'pipeline_tmp', animal, 'cell_candidates', filename)

print(f'LOADING FROM {src}')
cell_candidates = load(src)
print(f'TOTAL CELL CANDIDATES: {len(cell_candidates)}')
# Out:
# LOADING FROM /scratch/pipeline_tmp/CTB015/cell_candidates/extracted_cells_061.gz
# TOTAL CELL CANDIDATES: 166751

# %%
''' created with cell_utilities.py::filter_cell_candidates:
cell = {
    "animal": animal,
    "section": section_number,
    "area": object_area,
    "absolute_coordinates_YX": (
        absolute_coordinates[2] + segment_col,
        absolute_coordinates[0] + segment_row,
    ),
    "cell_shape_XY": (height, width),
    "image_CH3": difference_ch3[row_start:row_end, col_start:col_end].T,
    "image_CH1": difference_ch1[row_start:row_end, col_start:col_end].T,
    "mask": segment_mask.T,
}      
'''
img_all = cell_candidates[124928]
img_all
# Out:
# {'animal': 'CTB015',
#  'section': 61,
#  'area': 2,
#  'absolute_coordinates_YX': (33809, 20863),
#  'cell_shape_XY': (2, 1),
#  'image_CH3': Array([[ -56.38965 ,  100.61035 ,  166.84009 , ..., -183.91577 ,
#          -185.91577 , -117.91577 ],
#         [ -56.38965 ,  118.61035 , -105.15991 , ..., -134.91577 ,
#          -243.91577 , -268.91577 ],
#         [  73.61035 ,   60.61035 ,  -42.159912, ...,  -55.91577 ,
#          -189.91577 , -279.91577 ],
#         ...,
#         [2029.8936  , 1820.8936  ,  663.2002  , ...,    7.175049,
#           169.17505 ,   58.17505 ],
#         [1691.8936  , 1429.8936  ,  375.2002  , ...,  193.17505 ,
#           170.17505 ,   98.17505 ],
#         [ 869.89355 ,  514.89355 ,   28.200195, ...,  -54.82495 ,
#           101.17505 ,   54.17505 ]], dtype=float32),
#  'image_CH1': Array([[    5.3095703,  2080.3096   ,  3413.6406   , ...,  1184.0049   ,
#           1344.0049   ,  2434.005    ],
#         [  364.30957  ,  2040.3096   ,  3287.6406   , ...,   359.00488  ,
#           1337.0049   ,  2940.005    ],
#         [ 1401.3096   ,  2159.3096   ,  3154.6406   , ...,  -438.99512  ,
#            838.0049   ,  2541.005    ],
#         ...,
#         [-2427.6797   , -2121.6797   , -2144.3564   , ..., -3957.9492   ,
#          -3711.9492   , -3571.9492   ],
#         [-2320.6797   , -2493.6797   , -2510.3564   , ..., -3937.9492   ,
#          -3904.9492   , -3757.9492   ],
#         [-2360.6797   , -2287.6797   , -2237.3564   , ..., -3505.9492   ,
#          -3192.9492   , -3604.9492   ]], dtype=float32),
#  'mask': array([[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]])}

# %%
img = img_all['image_CH3']
plt.imshow(img, cmap='viridis')
plt.show()

# %%
img = img_all['image_CH1']
plt.imshow(img, cmap='viridis')
plt.show()

# %%
img = img_all['mask']
plt.imshow(img, cmap='viridis')
plt.show()
