# %%
# CREATED: 9-JUN-2023
# LAST EDIT: 12-JUN-2023
# AUTHOR: DUANE RINEHART, MBA (drinehart@ucsd.edu)

#PROOF OF CONCEPT FOR DASK IMAGE PROCESSING (INSTEAD OF IMAGE TILING)
#ref: https://examples.dask.org/applications/image-processing.html
#ref: https://saturncloud.io/blog/a-data-scientist-s-guide-to-lazy-evaluation-with-dask/

import dask
from dask import delayed
import dask.array as da
from dask.distributed import Client, LocalCluster
import os, time
from pathlib import Path
import imageio.v2 as imageio
import glob
import numpy as np
import matplotlib.pyplot as plt
import multiprocessing as mp

img_src_folder = "input"
cwd = os.getcwd()
input_path = Path(cwd, img_src_folder)
print(f'SRC IMAGE PATH: {input_path}')
max_n_workers = int(0.9 * mp.cpu_count())
max_client_ram = "32GB"
scratch_dir = "d:/temp"

start = time.time()
base_path_with_pattern = str(input_path) + '/*.tif'
image_paths = [files for files in glob.glob(base_path_with_pattern, recursive=False)]


def load_image(path):
    return imageio.imread(path)


def show_image(img_array):
    plt.imshow(img_array)
    plt.show()

#SETUP DASK CLUSTER (AUTOCLOSE)
with LocalCluster(
    n_workers=max_n_workers,
    processes=True,
    threads_per_worker=1,
    memory_limit=max_client_ram,
    local_directory=scratch_dir) as cluster, Client(cluster) as client:

    # Create delayed tasks for loading the images
    delayed_tasks = [delayed(load_image)(path) for path in image_paths]
    shape = dask.compute(delayed_tasks[0].shape) #GET SHAPE WITHOUT COMPUTING

    x_dim = shape[0][0]
    y_dim = shape[0][1]

    # Create a Dask array from the delayed tasks (NOTE: DELAYED)
    image_stack = [da.from_delayed(v, shape=(x_dim, y_dim), dtype='uint16') for v in delayed_tasks]


end = time.time()
print(f'TOTAL IMAGES: {len(delayed_tasks)}')
print(f'INDIVIDUAL IMAGE SHAPE: {x_dim, y_dim}')
print("Operation time: ", (end - start), "sec")
# Out:
# SRC IMAGE PATH: D:\dev\image_tiling\input
# D:\venv\cell_extractor\Lib\site-packages\distributed\node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 64843 instead
#   warnings.warn(
# TOTAL IMAGES: 10
# INDIVIDUAL IMAGE SHAPE: (33500, 55500)
# Operation time:  24.981878995895386 sec

# %%
correspondence = zip(image_paths, delayed_tasks)
for cnt, tpl_item in enumerate(correspondence):
    print(cnt, tpl_item)
# Out:
# 0 ('D:\\dev\\image_tiling\\input\\000.tif', Delayed('load_image-2cf1f12d-a47f-4c3c-8ec7-15b3aaf41a59'))
# 1 ('D:\\dev\\image_tiling\\input\\001.tif', Delayed('load_image-bab4fdeb-c580-4449-9f15-326404033fb0'))
# 2 ('D:\\dev\\image_tiling\\input\\002.tif', Delayed('load_image-f03fcceb-ba2c-4aed-a28e-25a7cdd873b3'))
# 3 ('D:\\dev\\image_tiling\\input\\003.tif', Delayed('load_image-78ebfb3e-c258-47b1-bd52-01f17035a083'))
# 4 ('D:\\dev\\image_tiling\\input\\004.tif', Delayed('load_image-434e6c5d-98e8-47d2-ac34-e468fe0e66ee'))
# 5 ('D:\\dev\\image_tiling\\input\\005.tif', Delayed('load_image-7a19500a-720a-48c8-aced-0ba912e1357e'))
# 6 ('D:\\dev\\image_tiling\\input\\006.tif', Delayed('load_image-3a45ce9f-f29b-4d6b-af7a-d33c9c763882'))
# 7 ('D:\\dev\\image_tiling\\input\\007.tif', Delayed('load_image-eb8e310d-b714-487c-b931-d5338abec93d'))
# 8 ('D:\\dev\\image_tiling\\input\\008.tif', Delayed('load_image-1fbd482a-55f0-4e40-9b42-823a93af2643'))
# 9 ('D:\\dev\\image_tiling\\input\\009.tif', Delayed('load_image-5aaf3c56-f982-479c-bd1c-efe85d3ed7aa'))

# %%
data = dask.compute(image_stack[0])[0] #FULL IMAGE
show_image(data)
data.shape
# Out:
# (33500, 55500)

# %%
#SPLIT IN 4 (NOTE: ROWS SLICE IS FIRST)

image_roi_1 = data[0:16750, 0:27750] #UPPER LEFT
#show_image(image_roi_1)

image_roi_2 = data[0:16750, 27750:55500] #UPPER RIGHT
#show_image(image_roi_2)

image_roi_3 = data[16750:33500, 0:27750] #LOWER LEFT
#show_image(image_roi_3)

image_roi_4 = data[16750:33500, 27750:55500] #LOWER RIGHT
#show_image(image_roi_4)

fig, ax = plt.subplots(nrows=2, ncols=2)
ax[0,0].imshow(image_roi_1)
ax[0,1].imshow(image_roi_2)
ax[1,0].imshow(image_roi_3)
ax[1,1].imshow(image_roi_4)
plt.show()

# %%
#MOVING WINDOW

start = time.time()
data = dask.compute(image_stack[0])[0] #FULL IMAGE

#SETUP DASK CLUSTER (AUTOCLOSE)
with LocalCluster(
    n_workers=max_n_workers,
    processes=True,
    threads_per_worker=1,
    memory_limit=max_client_ram,
    local_directory=scratch_dir) as cluster, Client(cluster) as client:


    #TUPLE SRC SHAPE EX. (33500, 55500)
    #SPLIT INTO TILES (ROWS x COLS)
    split_rows = 2
    split_cols = 2

    x_window = int(data.shape[0]/split_rows)
    y_window = int(data.shape[1]/split_cols)

    print(f'TILE WINDOW DIMENSIONS: {x_window, y_window}')


    fig, ax = plt.subplots(nrows=split_rows, ncols=split_cols)

    for row in range(split_rows):
        for col in range(split_cols):
            print(f'{row*x_window}:{x_window*(row+1)}, {col*y_window}:{y_window*(col+1)}')

            image_roi = data[(row*x_window):x_window*(row+1), (col*y_window):y_window*(col+1)]
            ax[row, col].imshow(image_roi)

plt.show()
end = time.time()
print("Operation time: ", (end - start), "sec")
# Out:
# D:\venv\cell_extractor\Lib\site-packages\distributed\node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 65038 instead
#   warnings.warn(
# TILE WINDOW DIMENSIONS: (16750, 27750)
# 0:16750, 0:27750
# 0:16750, 27750:55500
# 16750:33500, 0:27750
# 16750:33500, 27750:55500
# Operation time:  40.36067247390747 sec

# %%
#RECONSTRUCTING TILED IMAGES INTO SINGLE, LARGE IMAGE
#ref: https://github.com/VolkerH/DaskFusion/blob/main/DaskFusion_Example.ipynb

# %%
import pandas as pd
from pathlib import Path

input_file = Path('/net/birdstore/Active_Atlas_Data/cell_segmentation/DK52/CH3/000/', 'extracted_cells_0_threshold_2000.pkl')

obj = pd.read_pickle(input_file)

print(obj)
# Out:
# /net/birdstore/Active_Atlas_Data/cell_segmentation/DK52/CH3/000/extracted_cells_0_threshold_2000.pkl
# [[{'animal': 'DK52', 'section': 0, 'index': 0, 'label': 0, 'area': 1, 'row': 999, 'col': 31236, 'origin': array([14400,     0], dtype=int32), 'height': 1, 'width': 1, 'image_CH3': array([[ 267.30847 ,  236.30847 ,  260.30847 , ...,  524.0895  ,
#          524.0895  ,  527.0895  ],
#        [  54.444336,   65.444336,   65.444336, ...,  336.76367 ,
#          337.76367 ,  332.76367 ],
#        [  75.444336,   49.444336,   88.444336, ...,  509.76367 ,
#          366.76367 ,  345.76367 ],
#        ...,
#        [1805.9724  , 1746.9724  , 1905.9724  , ..., 1751.9751  ,
#         1772.9751  , 1988.9751  ],
#        [1899.9724  , 1791.9724  , 1734.9724  , ..., 1824.9751  ,
#         1862.9751  , 1834.9751  ],
#        [1902.9724  , 1904.9724  , 1886.9724  , ..., 1942.9751  ,
#         1761.9751  , 1662.9751  ]], dtype=float32), 'image_CH1': array([[ -566.6328 ,  -739.6328 , -1125.6328 , ...,   826.36816,
#           750.36816,  1517.3682 ],
#        [-1176.1836 , -1896.1836 , -1488.1836 , ...,  -215.14941,
#          -341.1494 ,   454.8506 ],
#        [-2240.1836 , -1397.1836 , -1751.1836 , ...,  -717.1494 ,
#          -172.14941,  -651.1494 ],
#        ...,
#        [20669.715  , 19646.715  , 18157.715  , ...,  6576.552  ,
#          6910.552  ,  6960.552  ],
#        [17269.715  , 16895.715  , 16581.715  , ...,  6854.552  ,
#          6663.552  ,  6381.552  ],
#        [15215.715  , 14732.715  , 14355.715  , ...,  7282.552  ,
#          7185.552  ,  6532.552  ]], dtype=float32), 'mask': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}, {'animal': 'DK52', 'section': 0, 'index': 1, 'label': 0, 'area': 1, 'row': 999, 'col': 31238, 'origin': array([14400,     0], dtype=int32), 'height': 1, 'width': 1, 'image_CH3': array([[ 260.30847 ,  252.30847 ,  259.69983 , ...,  527.0895  ,
#          782.0895  ,  790.0895  ],
#        [  65.444336,   65.444336,   72.63025 , ...,  332.76367 ,
#          396.76367 ,  585.7637  ],
#        [  88.444336,   50.444336,  113.63025 , ...,  345.76367 ,
#          531.7637  ,  409.76367 ],
#        ...,
#        [1905.9724  , 1912.9724  , 1805.3853  , ..., 1988.9751  ,
#         1740.9751  , 1795.9751  ],
#        [1734.9724  , 1908.9724  , 1914.3853  , ..., 1834.9751  ,
#         1651.9751  , 1672.9751  ],
#        [1886.9724  , 1902.9724  , 1983.3853  , ..., 1662.9751  ,
#         1715.9751  , 1890.9751  ]], dtype=float32), 'image_CH1': array([[-1125.6328 , -1118.6328 ,  -665.4619 , ...,  1517.3682 ,
#          1065.3682 ,  1235.3682 ],
#        [-1488.1836 , -2146.1836 , -1348.709  , ...,   454.8506 ,
#           162.85059,   374.8506 ],
#        [-1751.1836 , -1540.1836 , -1746.709  , ...,  -651.1494 ,
#           441.8506 ,   139.85059],
#        ...,
#        [18157.715  , 17203.715  , 15762.609  , ...,  6960.552  ,
#          6532.552  ,  5992.552  ],
#        [16581.715  , 15357.715  , 13817.609  , ...,  6381.552  ,
#          6693.552  ,  6343.552  ],
#        [14355.715  , 13442.715  , 12835.609  , ...,  6532.552  ,
#          6691.552  ,  6670.552  ]], dtype=float32), 'mask': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}, {'animal': 'DK52', 'section': 0, 'index': 2, 'label': 0, 'area': 1, 'row': 998, 'col': 31280, 'origin': array([14400,     0], dtype=int32), 'height': 1, 'width': 1, 'image_CH3': array([[ 537.7119  ,  494.7119  ,  282.7119  , ...,   97.12256 ,
#           29.122559,   29.122559],
#        [ 508.7119  ,  508.7119  ,  306.7119  , ...,   55.12256 ,
#          237.12256 ,  277.12256 ],
#        [ 346.19812 ,  339.19812 ,  374.19812 , ...,   50.04419 ,
#          138.04419 ,  130.04419 ],
#        ...,
#        [2195.9482  , 2065.9482  , 2018.9482  , ..., 1528.133   ,
#         1707.133   , 1645.133   ],
#        [2113.9482  , 1920.9482  , 2003.9482  , ..., 1652.133   ,
#         1561.133   , 1534.133   ],
#        [2198.9482  , 2104.9482  , 2003.9482  , ..., 1553.133   ,
#         1480.133   , 1490.133   ]], dtype=float32), 'image_CH1': array([[ 1166.3721,  1164.3721,   533.3721, ..., 54013.69  , 54013.69  ,
#         49266.69  ],
#        [ 2343.372 ,  1880.3721,   896.3721, ..., 54013.69  , 54013.69  ,
#         49509.69  ],
#        [ 1559.1992,  1156.1992,   676.1992, ..., 53026.05  , 53026.05  ,
#         47646.05  ],
#        ...,
#        [ 6933.3594,  7301.3594,  7102.3594, ...,  4958.496 ,  5064.496 ,
#          4475.496 ],
#        [ 6800.3594,  7089.3594,  6918.3594, ...,  4803.496 ,  4674.496 ,
#          4378.496 ],
#        [ 7245.3594,  6395.3594,  6415.3594, ...,  4911.496 ,  4695.496 ,
#          4502.496 ]], dtype=float32), 'mask': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}, {'animal': 'DK52', 'section': 0, 'index': 3, 'label': 0, 'area': 1, 'row': 1001, 'col': 31235, 'origin': array([14400,     0], dtype=int32), 'height': 1, 'width': 1, 'image_CH3': array([[  48.444336,   75.444336,   49.444336, ...,  343.76367 ,
#          509.76367 ,  366.76367 ],
#        [ 276.44434 ,  305.44434 ,   99.444336, ...,  337.76367 ,
#          432.76367 ,  342.76367 ],
#        [ 328.44434 ,  330.44434 ,  306.44434 , ...,  328.76367 ,
#          324.76367 ,  503.76367 ],
#        ...,
#        [1916.9724  , 1902.9724  , 1904.9724  , ..., 1822.9751  ,
#         1942.9751  , 1761.9751  ],
#        [1846.9724  , 1718.9724  , 1906.9724  , ..., 1935.9751  ,
#         1775.9751  , 1669.9751  ],
#        [1610.5603  , 1765.5603  , 1797.5603  , ..., 1680.522   ,
#         1555.522   , 1558.522   ]], dtype=float32), 'image_CH1': array([[-2757.1836 , -2240.1836 , -1397.1836 , ...,  -649.1494 ,
#          -717.1494 ,  -172.14941],
#        [-1456.1836 , -1487.1836 , -1088.1836 , ...,  -853.1494 ,
#          -883.1494 ,   165.85059],
#        [ -910.1836 , -1391.1836 , -1333.1836 , ...,  -683.1494 ,
#          -675.1494 ,  -447.1494 ],
#        ...,
#        [15928.715  , 15215.715  , 14732.715  , ...,  6835.552  ,
#          7282.552  ,  7185.552  ],
#        [13704.715  , 13523.715  , 12913.715  , ...,  7052.552  ,
#          7193.552  ,  6953.552  ],
#        [11633.199  , 11614.199  , 11303.199  , ...,  6421.8584 ,
#          7017.8584 ,  6001.8584 ]], dtype=float32), 'mask': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}, {'animal': 'DK52', 'section': 0, 'index': 4, 'label': 0, 'area': 2, 'row': 1003, 'col': 31219, 'origin': array([14400,     0], dtype=int32), 'height': 1, 'width': 2, 'image_CH3': array([[  61.530396,   63.444336,   55.444336, ...,  323.19812 ,
#          326.19812 ,  330.19812 ],
#        [  49.530396,  103.444336,  122.444336, ...,  564.1981  ,
#          569.1981  ,  593.1981  ],
#        [ 132.5304  ,  291.44434 ,  338.44434 , ...,  606.1981  ,
#          411.19812 ,  536.1981  ],
#        ...,
#        [1307.427   , 1265.5603  , 1283.5603  , ..., 2008.8206  ,
#         1990.8206  , 1839.8206  ],
#        [1270.427   , 1286.5603  , 1278.5603  , ..., 2068.8206  ,
#         1878.8206  , 2034.8206  ],
#        [1083.427   , 1276.5603  , 1278.5603  , ..., 2066.8206  ,
#         1823.8206  , 2071.8206  ]], dtype=float32), 'image_CH1': array([[ -874.9922  ,  -773.1836  ,  -531.1836  , ...,  -823.8008  ,
#          -639.8008  ,  -794.8008  ],
#        [ -940.9922  ,  -881.1836  ,  -824.1836  , ...,  -977.8008  ,
#          -240.80078 ,  -270.80078 ],
#        [ -671.9922  , -1063.1836  ,  -546.1836  , ...,   -29.800781,
#            84.19922 , -1114.8008  ],
#        ...,
#        [12527.148   , 13038.199   , 12127.199   , ...,  6421.252   ,
#          6141.252   ,  6797.252   ],
#        [10029.148   ,  9415.199   , 10270.199   , ...,  7168.252   ,
#          7224.252   ,  7377.252   ],
#        [ 8893.148   ,  7666.199   ,  8696.199   , ...,  6845.252   ,
#          6835.252   ,  6959.252   ]], dtype=float32), 'mask': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}, {'animal': 'DK52', 'section': 0, 'index': 5, 'label': 0, 'area': 809, 'row': 1024, 'col': 31235, 'origin': array([14400,     0], dtype=int32), 'height': 45, 'width': 57, 'image_CH3': array([[1169.668 , 1184.668 , 1152.668 , ..., 1450.3345, 1232.3345,
#         1172.3345],
#        [1164.668 , 1163.668 , 1171.668 , ..., 1441.3345, 1380.3345,
#         1376.3345],
#        [1408.668 , 1223.668 , 1173.668 , ..., 1455.3345, 1455.3345,
#         1471.3345],
#        ...,
#        [ 913.9397,  958.9397,  949.9397, ..., 1762.6738, 1743.6738,
#         1595.6738],
#        [ 731.9397,  744.9397,  950.9397, ..., 1625.6738, 1602.6738,
#         1476.6738],
#        [ 868.9397,  702.9397,  948.9397, ..., 1479.6738, 1487.6738,
#         1490.6738]], dtype=float32), 'image_CH1': array([[ 1.8216865e+03,  2.1126865e+03,  1.9346865e+03, ...,
#          3.1102920e+03,  2.9262920e+03,  2.8472920e+03],
#        [ 2.4656865e+03,  1.8726865e+03,  2.4786865e+03, ...,
#          3.1222920e+03,  3.0682920e+03,  3.0452920e+03],
#        [ 2.6356865e+03,  2.8726865e+03,  3.3906865e+03, ...,
#          3.2302920e+03,  3.1852920e+03,  3.5062920e+03],
#        ...,
#        [-1.8308594e+02,  4.9140625e+00,  6.3091406e+02, ...,
#          3.8535594e+04,  3.3459594e+04,  3.5432594e+04],
#        [-3.9408594e+02, -4.5708594e+02,  3.1791406e+02, ...,
#          2.8415596e+04,  2.6378596e+04,  3.2005596e+04],
#        [-3.4508594e+02, -5.7085938e+01, -4.3208594e+02, ...,
#          1.8228596e+04,  1.9329596e+04,  2.6003596e+04]], dtype=float32), 'mask': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}, {'animal': 'DK52', 'section': 0, 'index': 6, 'label': 0, 'area': 2, 'row': 1003, 'col': 31240, 'origin': array([14400,     0], dtype=int32), 'height': 2, 'width': 2, 'image_CH3': array([[ 313.63025,  343.63025,   85.63025, ...,  343.76367,  343.76367,
#          343.76367],
#        [ 338.63025,  328.63025,  196.63025, ...,  335.76367,  343.76367,
#          343.76367],
#        [ 329.63025,  332.63025,  502.63025, ...,  405.76367,  328.76367,
#          347.76367],
#        ...,
#        [1629.2891 , 2036.2891 , 1787.2891 , ..., 1646.522  , 1796.522  ,
#         1602.522  ],
#        [1575.2891 , 2024.2891 , 1791.2891 , ..., 1771.522  , 1845.522  ,
#         1771.522  ],
#        [1581.2891 , 1774.2891 , 1798.2891 , ..., 1839.522  , 1829.522  ,
#         1623.522  ]], dtype=float32), 'image_CH1': array([[-1634.709   , -1434.709   , -1375.709   , ...,  -640.1494  ,
#          -649.1494  ,  -610.1494  ],
#        [-1353.709   ,  -916.709   , -1541.709   , ...,   155.85059 ,
#           433.8506  ,  -395.1494  ],
#        [-1056.709   , -1266.709   ,  -841.709   , ...,    63.850586,
#          -231.14941 ,  -516.1494  ],
#        ...,
#        [ 9779.219   ,  8719.219   ,  8174.2188  , ...,  6350.8584  ,
#          6213.8584  ,  6109.8584  ],
#        [ 8284.219   ,  6775.2188  ,  6395.2188  , ...,  5796.8584  ,
#          5550.8584  ,  5626.8584  ],
#        [ 6909.2188  ,  6603.2188  ,  6568.2188  , ...,  5782.8584  ,
#          5650.8584  ,  6481.8584  ]], dtype=float32), 'mask': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}, {'animal': 'DK52', 'section': 0, 'index': 7, 'label': 0, 'area': 1, 'row': 1003, 'col': 31243, 'origin': array([14400,     0], dtype=int32), 'height': 1, 'width': 1, 'image_CH3': array([[ 304.63025,  338.63025,  181.63025, ...,  357.97278,  357.97278,
#          357.97278],
#        [ 381.63025,  259.63025,  326.63025, ...,  357.97278,  357.97278,
#          357.97278],
#        [ 622.63025,  211.63025,  288.63025, ...,  347.97278,  369.97278,
#          357.97278],
#        ...,
#        [1787.2891 , 1837.2891 , 1967.2891 , ..., 1580.4082 , 1616.4082 ,
#         1630.4082 ],
#        [1797.2891 , 1789.2891 , 1791.2891 , ..., 1599.4082 , 1631.4082 ,
#         1823.4082 ],
#        [1797.2891 , 1797.2891 , 1797.2891 , ..., 1601.4082 , 1821.4082 ,
#         1643.4082 ]], dtype=float32), 'image_CH1': array([[-1182.709   , -1343.709   , -1693.709   , ...,  -185.33203 ,
#           257.66797 ,  -653.33203 ],
#        [-1175.709   ,  -871.709   ,  -693.709   , ...,  -193.33203 ,
#           350.66797 ,  -193.33203 ],
#        [ -896.709   ,  -703.709   ,  -662.709   , ...,   -29.332031,
#          -107.33203 ,  -273.33203 ],
#        ...,
#        [ 7231.2188  ,  6730.2188  ,  7009.2188  , ...,  6198.004   ,
#          6520.004   ,  5500.004   ],
#        [ 6711.2188  ,  5677.2188  ,  5702.2188  , ...,  5215.004   ,
#          5590.004   ,  5540.004   ],
#        [ 5873.2188  ,  4611.2188  ,  4577.2188  , ...,  6150.004   ,
#          4801.004   ,  5555.004   ]], dtype=float32), 'mask': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}, {'animal': 'DK52', 'section': 0, 'index': 8, 'label': 0, 'area': 3, 'row': 1003, 'col': 31249, 'origin': array([14400,     0], dtype=int32), 'height': 2, 'width': 2, 'image_CH3': array([[ 360.63025,  176.63025,  306.63025, ...,  176.97278,  336.97278,
#          138.97278],
#        [ 351.63025,  235.63025,  321.63025, ...,  305.97278,  376.97278,
#          214.97278],
#        [ 310.63025,  320.63025,  315.63025, ...,  364.97278,  359.97278,
#          365.97278],
#        ...,
#        [1947.2891 , 1950.2891 , 1928.2891 , ..., 1599.4082 , 1599.4082 ,
#         1599.4082 ],
#        [1807.2891 , 1931.2891 , 1921.2891 , ..., 1599.4082 , 1599.4082 ,
#         1595.4082 ],
#        [1798.2891 , 1784.2891 , 1798.2891 , ..., 1599.4082 , 1594.4082 ,
#         1668.4082 ]], dtype=float32), 'image_CH1': array([[-1.2287090e+03, -1.2557090e+03, -1.2297090e+03, ...,
#          3.6679688e+00, -5.0332031e+01,  3.4066797e+02],
#        [-9.3470898e+02, -1.0077090e+03, -1.1127090e+03, ...,
#          2.2166797e+02,  5.1366797e+02,  9.1166797e+02],
#        [-8.1470898e+02, -4.8670898e+02, -6.9670898e+02, ...,
#          3.1866797e+02,  1.0356680e+03,  1.1006680e+03],
#        ...,
#        [ 5.1622188e+03,  5.7392188e+03,  5.3902188e+03, ...,
#          5.7490039e+03,  5.3920039e+03,  4.9450039e+03],
#        [ 4.3412188e+03,  5.4342188e+03,  5.1682188e+03, ...,
#          5.5130039e+03,  5.5860039e+03,  5.2480039e+03],
#        [ 4.6722188e+03,  4.6342188e+03,  4.9712188e+03, ...,
#          5.4850039e+03,  5.6540039e+03,  5.2170039e+03]], dtype=float32), 'mask': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}, {'animal': 'DK52', 'section': 0, 'index': 9, 'label': 0, 'area': 1, 'row': 1003, 'col': 31277, 'origin': array([14400,     0], dtype=int32), 'height': 1, 'width': 1, 'image_CH3': array([[ 535.2865 ,  587.2865 ,  381.2865 , ...,  123.04419,  120.04419,
#          129.04419],
#        [ 596.2865 ,  594.2865 ,  594.2865 , ...,  253.04419,  165.04419,
#          113.04419],
#        [ 593.2865 ,  589.2865 ,  788.2865 , ...,  317.0442 ,  349.0442 ,
#          174.04419],
#        ...,
#        [2026.6458 , 2030.6458 , 1782.6458 , ..., 1631.6458 , 1370.6458 ,
#         1382.6458 ],
#        [2083.6458 , 2069.6458 , 2046.6458 , ..., 1637.6458 , 1530.6458 ,
#         1386.6458 ],
#        [1838.6458 , 1847.6458 , 2053.6458 , ..., 1649.6458 , 1502.6458 ,
#         1379.6458 ]], dtype=float32), 'image_CH1': array([[ 1684.2666,  1922.2666,  1349.2666, ..., 53026.05  , 53026.05  ,
#         53026.05  ],
#        [ 1837.2666,  1816.2666,  1462.2666, ..., 53026.05  , 53026.05  ,
#         53026.05  ],
#        [ 1624.2666,  2358.2666,  1948.2666, ..., 53026.05  , 53026.05  ,
#         53026.05  ],
#        ...,
#        [ 5705.758 ,  5356.758 ,  5916.758 , ...,  4247.2637,  3941.2637,
#          4218.2637],
#        [ 5852.758 ,  5524.758 ,  6373.758 , ...,  4789.2637,  3795.2637,
#          4764.2637],
#        [ 6301.758 ,  6418.758 ,  6000.758 , ...,  4957.2637,  3594.2637,
#          4718.2637]], dtype=float32), 'mask': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}, {'animal': 'DK52', 'section': 0, 'index': 10, 'label': 0, 'area': 4, 'row': 1002, 'col': 31280, 'origin': array([14400,     0], dtype=int32), 'height': 3, 'width': 3, 'image_CH3': array([[ 353.19812,  349.19812,  361.19812, ...,  127.04419,   83.04419,
#           87.04419],
#        [ 557.1981 ,  607.1981 ,  617.1981 , ...,  126.04419,  127.04419,
#          134.04419],
#        [ 598.1981 ,  595.1981 ,  590.1981 , ...,  125.04419,  125.04419,
#          125.04419],
#        ...,
#        [2113.9482 , 2046.9482 , 2397.9482 , ..., 1740.133  , 1473.133  ,
#         1419.133  ],
#        [1870.8206 , 2056.8206 , 2019.8206 , ..., 1484.6458 , 1560.6458 ,
#         1391.6458 ],
#        [2065.8206 , 2026.8206 , 1874.8206 , ..., 1376.6458 , 1461.6458 ,
#         1370.6458 ]], dtype=float32), 'image_CH1': array([[ 1517.1992,  1540.1992,  1537.1992, ..., 53026.05  , 52073.05  ,
#         44692.05  ],
#        [ 1234.1992,  1518.1992,  1799.1992, ..., 53026.05  , 48743.05  ,
#         42543.05  ],
#        [ 1989.1992,  2302.1992,  2167.1992, ..., 52124.05  , 46737.05  ,
#         41650.05  ],
#        ...,
#        [ 6392.3594,  6278.3594,  7050.3594, ...,  4648.496 ,  4964.496 ,
#          4394.496 ],
#        [ 5870.252 ,  5167.252 ,  5973.252 , ...,  3967.2637,  4458.2637,
#          3980.2637],
#        [ 6003.252 ,  6097.252 ,  6311.252 , ...,  4055.2637,  4313.2637,
#          4249.2637]], dtype=float32), 'mask': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}, {'animal': 'DK52', 'section': 0, 'index': 11, 'label': 0, 'area': 5, 'row': 1005, 'col': 31217, 'origin': array([14400,     0], dtype=int32), 'height': 3, 'width': 3, 'image_CH3': array([[  41.530396,  284.5304  ,  132.5304  , ...,  599.1981  ,
#          598.1981  ,  606.1981  ],
#        [ 115.530396,  271.5304  ,  320.5304  , ...,  582.1981  ,
#          595.1981  ,  609.1981  ],
#        [ 310.5304  ,  324.5304  ,  318.5304  , ...,  673.1981  ,
#          589.1981  ,  602.1981  ],
#        ...,
#        [1300.427   , 1221.427   , 1083.427   , ..., 2069.8206  ,
#         1906.8206  , 2066.8206  ],
#        [1050.427   , 1047.427   , 1273.427   , ..., 1898.8206  ,
#         1800.8206  , 2053.8206  ],
#        [1237.427   , 1058.427   , 1272.427   , ..., 1974.8206  ,
#         2003.8206  , 1902.8206  ]], dtype=float32), 'image_CH1': array([[-390.9922   , -211.99219  , -671.9922   , ...,  440.19922  ,
#          565.1992   ,  -29.800781 ],
#        [-699.9922   , -555.9922   , -263.9922   , ...,  211.19922  ,
#          122.19922  ,  118.19922  ],
#        [-461.9922   , -361.9922   ,  -14.9921875, ...,  -51.80078  ,
#         -163.80078  ,  107.19922  ],
#        ...,
#        [7727.1484   , 8136.1484   , 8893.148    , ..., 6618.252    ,
#         7279.252    , 6845.252    ],
#        [6597.1484   , 6376.1484   , 6735.1484   , ..., 6472.252    ,
#         6807.252    , 7049.252    ],
#        [5333.1484   , 4770.1484   , 5205.1484   , ..., 7276.252    ,
#         7019.252    , 7081.252    ]], dtype=float32), 'mask': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}, {'animal': 'DK52', 'section': 0, 'index': 12, 'label': 0, 'area': 1, 'row': 1004, 'col': 31234, 'origin': array([14400,     0], dtype=int32), 'height': 1, 'width': 1, 'image_CH3': array([[ 364.44434,  321.44434,  322.44434, ...,  488.76367,  522.7637 ,
#          371.76367],
#        [ 314.44434,  316.44434,  330.44434, ...,  424.76367,  456.76367,
#          340.76367],
#        [ 376.44434,  302.44434,  523.44434, ...,  364.76367,  431.76367,
#          524.7637 ],
#        ...,
#        [1530.5603 , 1572.5603 , 1814.5603 , ..., 1818.522  , 1549.522  ,
#         1572.522  ],
#        [1535.5603 , 1533.5603 , 1569.5603 , ..., 1705.522  , 1699.522  ,
#         1717.522  ],
#        [1535.5603 , 1535.5603 , 1526.5603 , ..., 1686.522  , 1840.522  ,
#         1703.522  ]], dtype=float32), 'image_CH1': array([[-1416.1836,  -977.1836,  -924.1836, ...,  -686.1494,  -430.1494,
#          -539.1494],
#        [ -966.1836, -1024.1836, -1091.1836, ...,  -634.1494,  -284.1494,
#          -413.1494],
#        [ -972.1836,  -161.1836,  -400.1836, ...,  -368.1494,  -290.1494,
#          -699.1494],
#        ...,
#        [ 9729.199 , 10025.199 ,  9289.199 , ...,  6677.8584,  5797.8584,
#          6582.8584],
#        [ 8634.199 ,  8474.199 ,  8727.199 , ...,  7085.8584,  6936.8584,
#          6803.8584],
#        [ 6713.199 ,  6367.199 ,  6402.199 , ...,  6782.8584,  7453.8584,
#          6651.8584]], dtype=float32), 'mask': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}, {'animal': 'DK52', 'section': 0, 'index': 13, 'label': 0, 'area': 1, 'row': 1005, 'col': 31287, 'origin': array([14400,     0], dtype=int32), 'height': 1, 'width': 1, 'image_CH3': array([[ 465.19812 ,  561.1981  ,  605.1981  , ...,  166.344   ,
#           -8.656006,   82.343994],
#        [ 603.1981  ,  610.1981  ,  481.19812 , ...,  167.344   ,
#          158.344   ,  173.344   ],
#        [ 586.1981  ,  598.1981  ,  480.19812 , ...,  286.344   ,
#          163.344   ,  156.344   ],
#        ...,
#        [2069.8206  , 1824.8206  , 2067.8206  , ..., 1435.1577  ,
#         1435.1577  , 1435.1577  ],
#        [2060.8206  , 1812.8206  , 2071.8206  , ..., 1413.1577  ,
#         1462.1577  , 1429.1577  ],
#        [1997.8206  , 1908.8206  , 2072.8206  , ..., 1222.1577  ,
#         1612.1577  , 1474.1577  ]], dtype=float32), 'image_CH1': array([[ 3.8319922e+02, -2.7080078e+02, -7.8007812e+00, ...,
#          1.6837984e+04,  1.3840983e+04,  1.0572983e+04],
#        [ 4.7219922e+02, -2.8580078e+02,  4.6319922e+02, ...,
#          1.5831983e+04,  1.2425983e+04,  8.7439834e+03],
#        [ 6.6819922e+02,  2.6819922e+02,  6.0819922e+02, ...,
#          1.4510983e+04,  1.1867983e+04,  8.4859834e+03],
#        ...,
#        [ 6.7692520e+03,  6.6142520e+03,  6.6002520e+03, ...,
#          4.5480908e+03,  4.0690908e+03,  4.3110908e+03],
#        [ 6.3162520e+03,  6.5752520e+03,  6.3192520e+03, ...,
#          4.0410908e+03,  3.9510908e+03,  4.0340908e+03],
#        [ 5.7272520e+03,  6.6952520e+03,  6.9732520e+03, ...,
#          4.2680908e+03,  4.1080908e+03,  4.6320908e+03]], dtype=float32), 'mask': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}, {'animal': 'DK52', 'section': 0, 'index': 14, 'label': 0, 'area': 1, 'row': 1004, 'col': 31295, 'origin': array([14400,     0], dtype=int32), 'height': 1, 'width': 1, 'image_CH3': array([[ 548.1981  ,  564.1981  ,  569.1981  , ...,  -18.656006,
#         -111.656006, -104.656006],
#        [ 598.1981  ,  606.1981  ,  411.19812 , ...,  -26.656006,
#          -14.656006,  -53.656006],
#        [ 595.1981  ,  609.1981  ,  393.19812 , ...,   62.343994,
#          129.344   ,   -5.656006],
#        ...,
#        [1995.8206  , 2068.8206  , 1878.8206  , ..., 1335.1577  ,
#         1299.1577  , 1452.1577  ],
#        [1906.8206  , 2066.8206  , 1823.8206  , ..., 1255.1577  ,
#         1329.1577  , 1312.1577  ],
#        [1800.8206  , 2053.8206  , 1608.8206  , ..., 1524.1577  ,
#         1192.1577  , 1280.1577  ]], dtype=float32), 'image_CH1': array([[-443.80078 , -977.8008  , -240.80078 , ...,  354.9834  ,
#          -89.0166  , -359.0166  ],
#        [ 565.1992  ,  -29.800781,   84.19922 , ...,  628.9834  ,
#          133.9834  , -312.0166  ],
#        [ 122.19922 ,  118.19922 ,  372.19922 , ..., 1056.9834  ,
#          180.9834  , -249.0166  ],
#        ...,
#        [7303.252   , 7168.252   , 7224.252   , ..., 4102.091   ,
#         3847.0908  , 3908.0908  ],
#        [7279.252   , 6845.252   , 6835.252   , ..., 3902.0908  ,
#         3225.0908  , 3543.0908  ],
#        [6807.252   , 7049.252   , 7015.252   , ..., 3750.0908  ,
#         3449.0908  , 3832.0908  ]], dtype=float32), 'mask': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}, {'animal': 'DK52', 'section': 0, 'index': 15, 'label': 0, 'area': 4, 'row': 1006, 'col': 31232, 'origin': array([14400,     0], dtype=int32), 'height': 2, 'width': 3, 'image_CH3': array([[ 309.44434,  487.44434,  376.44434, ...,  560.7637 ,  525.7637 ,
#          364.76367],
#        [ 463.44434,  593.44434,  562.44434, ...,  609.7637 ,  513.7637 ,
#          460.76367],
#        [ 418.44434,  499.44434,  592.44434, ...,  680.7637 ,  561.7637 ,
#          534.7637 ],
#        ...,
#        [1622.5603 , 1529.5603 , 1535.5603 , ..., 1651.522  , 1821.522  ,
#         1686.522  ],
#        [1530.5603 , 1535.5603 , 1535.5603 , ..., 1738.522  , 1734.522  ,
#         1834.522  ],
#        [1547.5603 , 1541.5603 , 1535.5603 , ..., 1672.522  , 1549.522  ,
#         1814.522  ]], dtype=float32), 'image_CH1': array([[-1.0671836e+03, -8.5218359e+02, -9.7218359e+02, ...,
#         -4.3114941e+02, -4.3714941e+02, -3.6814941e+02],
#        [-7.3818359e+02, -6.4418359e+02, -7.0718359e+02, ...,
#         -2.9814941e+02, -2.1714941e+02, -7.8149414e+01],
#        [-8.0518359e+02, -7.1218359e+02, -4.9718359e+02, ...,
#          3.4485059e+02,  1.3885059e+02, -2.1494141e+00],
#        ...,
#        [ 8.2191992e+03,  7.4491992e+03,  6.7131992e+03, ...,
#          6.1118584e+03,  6.3938584e+03,  6.7828584e+03],
#        [ 6.7011992e+03,  6.9251992e+03,  6.0081992e+03, ...,
#          6.3798584e+03,  6.6948584e+03,  6.4738584e+03],
#        [ 5.9031992e+03,  5.8961992e+03,  4.9941992e+03, ...,
#          6.6718584e+03,  6.8478584e+03,  6.0468584e+03]], dtype=float32), 'mask': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}, {'animal': 'DK52', 'section': 0, 'index': 16, 'label': 0, 'area': 1, 'row': 1006, 'col': 31277, 'origin': array([14400,     0], dtype=int32), 'height': 1, 'width': 1, 'image_CH3': array([[ 591.2865 ,  589.2865 ,  595.2865 , ...,  231.04419,  322.0442 ,
#          362.0442 ],
#        [ 750.2865 ,  859.2865 ,  670.2865 , ...,  321.0442 ,  348.0442 ,
#          287.0442 ],
#        [ 742.2865 ,  870.2865 ,  689.2865 , ...,  387.0442 ,  400.0442 ,
#          229.04419],
#        ...,
#        [1811.6458 , 2029.6458 , 2070.6458 , ..., 1516.6458 , 1524.6458 ,
#         1388.6458 ],
#        [1800.6458 , 1830.6458 , 1822.6458 , ..., 1395.6458 , 1484.6458 ,
#         1541.6458 ],
#        [2029.6458 , 2036.6458 , 1815.6458 , ..., 1388.6458 , 1508.6458 ,
#         1500.6458 ]], dtype=float32), 'image_CH1': array([[ 1861.2666,  2082.2666,  2173.2666, ..., 53026.05  , 53026.05  ,
#         51572.05  ],
#        [ 2358.2666,  2055.2666,  1364.2666, ..., 53026.05  , 52970.05  ,
#         49180.05  ],
#        [ 2149.2666,  2413.2666,  2798.2666, ..., 52495.05  , 50055.05  ,
#         46152.05  ],
#        ...,
#        [ 5568.758 ,  5592.758 ,  5368.758 , ...,  4270.2637,  4203.2637,
#          4230.2637],
#        [ 5510.758 ,  5814.758 ,  6256.758 , ...,  4391.2637,  4408.2637,
#          4237.2637],
#        [ 5281.758 ,  5994.758 ,  5885.758 , ...,  4462.2637,  3752.2637,
#          3942.2637]], dtype=float32), 'mask': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}, {'animal': 'DK52', 'section': 0, 'index': 17, 'label': 0, 'area': 2, 'row': 1006, 'col': 31280, 'origin': array([14400,     0], dtype=int32), 'height': 1, 'width': 2, 'image_CH3': array([[ 607.1981 ,  597.1981 ,  591.1981 , ...,  197.04419,  269.0442 ,
#          223.04419],
#        [ 761.1981 ,  685.1981 ,  589.1981 , ...,  127.04419,  141.04419,
#          135.04419],
#        [ 601.1981 ,  613.1981 ,  603.1981 , ...,  215.04419,  361.0442 ,
#          230.04419],
#        ...,
#        [2067.8206 , 1820.8206 , 1814.8206 , ..., 1379.6458 , 1564.6458 ,
#         1402.6458 ],
#        [2053.8206 , 2066.8206 , 1826.8206 , ..., 1400.6458 , 1459.6458 ,
#         1376.6458 ],
#        [1832.8206 , 2032.8206 , 1857.8206 , ..., 1384.6458 , 1377.6458 ,
#         1378.6458 ]], dtype=float32), 'image_CH1': array([[ 1848.1992,  2193.1992,  2528.1992, ..., 47189.05  , 41466.05  ,
#         35775.05  ],
#        [ 1307.1992,  2745.1992,  3043.1992, ..., 43367.05  , 38110.05  ,
#         33319.05  ],
#        [ 1915.1992,  1796.1992,  2753.1992, ..., 40944.05  , 35577.05  ,
#         31090.05  ],
#        ...,
#        [ 6241.252 ,  6422.252 ,  6341.252 , ...,  3850.2637,  4037.2637,
#          3509.2637],
#        [ 6252.252 ,  5826.252 ,  6733.252 , ...,  4310.2637,  3827.2637,
#          4763.2637],
#        [ 5997.252 ,  6020.252 ,  5998.252 , ...,  4524.2637,  3844.2637,
#          4159.2637]], dtype=float32), 'mask': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}, {'animal': 'DK52', 'section': 0, 'index': 18, 'label': 0, 'area': 1, 'row': 1006, 'col': 31303, 'origin': array([14400,     0], dtype=int32), 'height': 1, 'width': 1, 'image_CH3': array([[ 617.7637 ,  446.76367,  484.76367, ...,   86.27954,   50.27954,
#          -62.72046],
#        [ 603.7637 ,  612.7637 ,  459.76367, ...,   97.27954,   74.27954,
#          -72.72046],
#        [ 599.7637 ,  599.7637 ,  603.7637 , ...,   68.27954,  216.27954,
#           66.27954],
#        ...,
#        [1836.522  , 1797.522  , 1789.522  , ..., 1237.9001 , 1240.9001 ,
#         1234.9001 ],
#        [1819.522  , 1603.522  , 1594.522  , ..., 1234.9001 , 1437.9001 ,
#         1282.9001 ],
#        [1836.522  , 1831.522  , 1836.522  , ..., 1276.9001 , 1289.9001 ,
#         1242.9001 ]], dtype=float32), 'image_CH1': array([[-101.149414, -136.14941 , -391.1494  , ..., -196.97168 ,
#         -498.97168 , -445.97168 ],
#        [-196.14941 , -440.1494  , -253.14941 , ...,  104.02832 ,
#         -229.97168 , -805.9717  ],
#        [ 831.8506  , -111.149414, -271.1494  , ..., -160.97168 ,
#         -161.97168 , -303.97168 ],
#        ...,
#        [6403.8584  , 7226.8584  , 7081.8584  , ..., 4239.0938  ,
#         3906.0938  , 4385.0938  ],
#        [7525.8584  , 7158.8584  , 6981.8584  , ..., 3862.0938  ,
#         4222.0938  , 3862.0938  ],
#        [6406.8584  , 6372.8584  , 7141.8584  , ..., 4428.0938  ,
#         3848.0938  , 3145.0938  ]], dtype=float32), 'mask': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}, {'animal': 'DK52', 'section': 0, 'index': 19, 'label': 0, 'area': 1, 'row': 1009, 'col': 31204, 'origin': array([14400,     0], dtype=int32), 'height': 1, 'width': 1, 'image_CH3': array([[  61.530396,   46.530396,  128.5304  , ...,  867.1981  ,
#          728.1981  ,  622.1981  ],
#        [  43.530396,  119.530396,  283.5304  , ...,  853.1981  ,
#          857.1981  ,  863.1981  ],
#        [  97.530396,  275.5304  ,  337.5304  , ...,  852.1981  ,
#          848.1981  ,  870.1981  ],
#        ...,
#        [ 757.427   ,  505.427   ,  604.427   , ..., 1821.8206  ,
#         2041.8206  , 1848.8206  ],
#        [ 672.427   ,  614.427   ,  666.427   , ..., 1798.8206  ,
#         2028.8206  , 1847.8206  ],
#        [ 605.427   ,  758.427   ,  526.427   , ..., 1865.8206  ,
#         1824.8206  , 1778.8206  ]], dtype=float32), 'image_CH1': array([[-1121.9922  ,  -477.9922  ,   -53.992188, ...,  2511.1992  ,
#          2402.1992  ,  2569.1992  ],
#        [-1299.9922  , -1304.9922  ,  -882.9922  , ...,  3048.1992  ,
#          2565.1992  ,  1820.1992  ],
#        [-1430.9922  , -1414.9922  , -1460.9922  , ...,  2454.1992  ,
#          2680.1992  ,  3163.1992  ],
#        ...,
#        [  788.14844 ,  1313.1484  ,   745.14844 , ...,  6021.252   ,
#          6059.252   ,  6405.252   ],
#        [  165.14844 ,  1042.1484  ,   936.14844 , ...,  5402.252   ,
#          5715.252   ,  6343.252   ],
#        [  321.14844 ,  -106.85156 ,   869.14844 , ...,  5846.252   ,
#          7080.252   ,  6906.252   ]], dtype=float32), 'mask': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}, {'animal': 'DK52', 'section': 0, 'index': 20, 'label': 0, 'area': 1, 'row': 1009, 'col': 31206, 'origin': array([14400,     0], dtype=int32), 'height': 1, 'width': 1, 'image_CH3': array([[ 128.5304,  283.5304,  335.5304, ...,  622.1981,  628.1981,
#          765.1981],
#        [ 283.5304,  336.5304,  210.5304, ...,  863.1981,  864.1981,
#          860.1981],
#        [ 337.5304,  341.5304,  155.5304, ...,  870.1981,  888.1981,
#          853.1981],
#        ...,
#        [ 604.427 ,  497.427 ,  763.427 , ..., 1848.8206, 2017.8206,
#         2034.8206],
#        [ 666.427 ,  636.427 ,  636.427 , ..., 1847.8206, 1797.8206,
#         1840.8206],
#        [ 526.427 ,  754.427 ,  520.427 , ..., 1778.8206, 1807.8206,
#         1980.8206]], dtype=float32), 'image_CH1': array([[  -53.992188,  -382.9922  ,  -672.9922  , ...,  2569.1992  ,
#          2317.1992  ,  1856.1992  ],
#        [ -882.9922  ,  -838.9922  ,  -784.9922  , ...,  1820.1992  ,
#          1580.1992  ,  1756.1992  ],
#        [-1460.9922  , -1049.9922  ,  -685.9922  , ...,  3163.1992  ,
#          2772.1992  ,  2053.1992  ],
#        ...,
#        [  745.14844 ,  1686.1484  ,  1999.1484  , ...,  6405.252   ,
#          6453.252   ,  7119.252   ],
#        [  936.14844 ,   695.14844 ,  1440.1484  , ...,  6343.252   ,
#          7151.252   ,  8707.252   ],
#        [  869.14844 ,   446.14844 ,   542.14844 , ...,  6906.252   ,
#          8951.252   , 13365.252   ]], dtype=float32), 'mask': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}, {'animal': 'DK52', 'section': 0, 'index': 21, 'label': 0, 'area': 2, 'row': 1008, 'col': 31208, 'origin': array([14400,     0], dtype=int32), 'height': 2, 'width': 1, 'image_CH3': array([[ 251.5304,  223.5304,  303.5304, ...,  722.1981,  668.1981,
#          693.1981],
#        [ 335.5304,  334.5304,  328.5304, ...,  765.1981,  875.1981,
#          883.1981],
#        [ 210.5304,  243.5304,  331.5304, ...,  860.1981,  856.1981,
#          864.1981],
#        ...,
#        [ 762.427 ,  623.427 ,  923.427 , ..., 1854.8206, 1784.8206,
#         1874.8206],
#        [ 763.427 ,  663.427 ,  873.427 , ..., 2034.8206, 1896.8206,
#         2053.8206],
#        [ 636.427 ,  616.427 ,  748.427 , ..., 1840.8206, 2034.8206,
#         2082.8206]], dtype=float32), 'image_CH1': array([[-3.0399219e+02, -2.0199219e+02, -6.7299219e+02, ...,
#          1.3081992e+03,  1.4181992e+03,  8.3119922e+02],
#        [-6.7299219e+02,  1.0078125e+00, -5.2599219e+02, ...,
#          1.8561992e+03,  1.1891992e+03,  7.5519922e+02],
#        [-7.8499219e+02, -3.6899219e+02, -4.9699219e+02, ...,
#          1.7561992e+03,  1.5161992e+03,  8.0719922e+02],
#        ...,
#        [ 2.2751484e+03,  2.0421484e+03,  3.1881484e+03, ...,
#          6.8592520e+03,  6.6322520e+03,  6.8712520e+03],
#        [ 1.9991484e+03,  1.3191484e+03,  2.1321484e+03, ...,
#          7.1192520e+03,  7.7462520e+03,  7.5032520e+03],
#        [ 1.4401484e+03,  1.2861484e+03,  1.5161484e+03, ...,
#          8.7072520e+03,  1.0272252e+04,  1.1583252e+04]], dtype=float32), 'mask': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}, {'animal': 'DK52', 'section': 0, 'index': 22, 'label': 0, 'area': 1, 'row': 1009, 'col': 31250, 'origin': array([14400,     0], dtype=int32), 'height': 1, 'width': 1, 'image_CH3': array([[ 681.63025,  834.63025,  804.63025, ...,  622.9728 ,  517.9728 ,
#          532.9728 ],
#        [ 720.63025,  860.63025,  855.63025, ...,  608.9728 ,  614.9728 ,
#          617.9728 ],
#        [ 783.63025,  850.63025,  849.63025, ...,  679.9728 ,  700.9728 ,
#          673.9728 ],
#        ...,
#        [1794.2891 , 1797.2891 , 1789.2891 , ..., 1656.4082 , 1730.4082 ,
#         1560.4082 ],
#        [1802.2891 , 1797.2891 , 1795.2891 , ..., 1543.4082 , 1415.4082 ,
#         1376.4082 ],
#        [1778.2891 , 1798.2891 , 1790.2891 , ..., 1428.4082 , 1545.4082 ,
#         1617.4082 ]], dtype=float32), 'image_CH1': array([[-1.62708984e+02, -1.20708984e+02, -1.38708984e+02, ...,
#          1.26366797e+03,  2.41266797e+03,  3.91366797e+03],
#        [ 6.39291016e+02,  2.78291016e+02, -7.08984375e-01, ...,
#          1.93666797e+03,  2.95466797e+03,  3.93666797e+03],
#        [ 1.03729102e+03,  9.18291016e+02,  6.37291016e+02, ...,
#          2.12066797e+03,  2.63466797e+03,  3.83766797e+03],
#        ...,
#        [ 4.72021875e+03,  4.59221875e+03,  4.59121875e+03, ...,
#          6.58500391e+03,  5.52500391e+03,  5.01700391e+03],
#        [ 4.46421875e+03,  4.40121875e+03,  4.10421875e+03, ...,
#          6.38700391e+03,  6.49700391e+03,  4.91700391e+03],
#        [ 3.93721875e+03,  4.11621875e+03,  3.82721875e+03, ...,
#          5.39300391e+03,  5.91900391e+03,  5.69300391e+03]], dtype=float32), 'mask': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}, {'animal': 'DK52', 'section': 0, 'index': 23, 'label': 0, 'area': 13, 'row': 1014, 'col': 31251, 'origin': array([14400,     0], dtype=int32), 'height': 11, 'width': 5, 'image_CH3': array([[ 960.63025,  892.63025,  999.63025, ...,  854.9728 ,  769.9728 ,
#          794.9728 ],
#        [1086.6302 , 1053.6302 , 1106.6302 , ...,  818.9728 ,  675.9728 ,
#          730.9728 ],
#        [1099.6302 , 1059.6302 ,  932.63025, ...,  867.9728 ,  985.9728 ,
#          977.9728 ],
#        ...,
#        [1683.2891 , 1603.2891 , 1734.2891 , ..., 1557.4082 , 1706.4082 ,
#         1577.4082 ],
#        [1721.2891 , 1693.2891 , 1785.2891 , ..., 1473.4082 , 1489.4082 ,
#         1614.4082 ],
#        [1833.2891 , 1710.2891 , 1725.2891 , ..., 1616.4082 , 1574.4082 ,
#         1507.4082 ]], dtype=float32), 'image_CH1': array([[1304.291 , 1501.291 , 1393.291 , ..., 3648.668 , 4076.668 ,
#         5165.668 ],
#        [1304.291 , 1261.291 , 1903.291 , ..., 2867.668 , 4123.668 ,
#         5169.668 ],
#        [1814.291 , 1581.291 , 1874.291 , ..., 3811.668 , 4470.668 ,
#         5287.668 ],
#        ...,
#        [3792.2188, 3585.2188, 4288.2188, ..., 5950.004 , 5241.004 ,
#         5825.004 ],
#        [3984.2188, 3447.2188, 3800.2188, ..., 6405.004 , 6219.004 ,
#         6037.004 ],
#        [3558.2188, 3318.2188, 3121.2188, ..., 7551.004 , 7110.004 ,
#         6645.004 ]], dtype=float32), 'mask': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}, {'animal': 'DK52', 'section': 0, 'index': 24, 'label': 0, 'area': 1, 'row': 1008, 'col': 31283, 'origin': array([14400,     0], dtype=int32), 'height': 1, 'width': 1, 'image_CH3': array([[ 582.1981,  729.1981,  722.1981, ...,  138.344 ,  284.344 ,
#          422.344 ],
#        [ 622.1981,  628.1981,  765.1981, ...,  267.344 ,  276.344 ,
#          303.344 ],
#        [ 863.1981,  864.1981,  860.1981, ...,  413.344 ,  301.344 ,
#          152.344 ],
#        ...,
#        [1798.8206, 1840.8206, 1854.8206, ..., 1430.1577, 1427.1577,
#         1441.1577],
#        [1848.8206, 2017.8206, 2034.8206, ..., 1619.1577, 1490.1577,
#         1436.1577],
#        [1847.8206, 1797.8206, 1840.8206, ..., 1481.1577, 1439.1577,
#         1447.1577]], dtype=float32), 'image_CH1': array([[ 2889.1992,  2131.1992,  1308.1992, ..., 27800.984 , 24098.984 ,
#         20442.984 ],
#        [ 2569.1992,  2317.1992,  1856.1992, ..., 25429.984 , 21311.984 ,
#         19053.984 ],
#        [ 1820.1992,  1580.1992,  1756.1992, ..., 23831.984 , 19709.984 ,
#         17154.984 ],
#        ...,
#        [ 6534.252 ,  6702.252 ,  6859.252 , ...,  4652.091 ,  5018.091 ,
#          4426.091 ],
#        [ 6405.252 ,  6453.252 ,  7119.252 , ...,  4087.0908,  4267.091 ,
#          4155.091 ],
#        [ 6343.252 ,  7151.252 ,  8707.252 , ...,  4282.091 ,  4440.091 ,
#          4181.091 ]], dtype=float32), 'mask': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}, {'animal': 'DK52', 'section': 0, 'index': 25, 'label': 0, 'area': 2, 'row': 1010, 'col': 31211, 'origin': array([14400,     0], dtype=int32), 'height': 2, 'width': 2, 'image_CH3': array([[ 276.5304,  300.5304,  320.5304, ...,  769.1981,  797.1981,
#          711.1981],
#        [ 320.5304,  319.5304,  318.5304, ...,  856.1981,  859.1981,
#          794.1981],
#        [ 318.5304,  318.5304,  318.5304, ...,  982.1981,  929.1981,
#          842.1981],
#        ...,
#        [ 780.427 ,  693.427 ,  832.427 , ..., 2084.8206, 2087.8206,
#         2089.8206],
#        [ 608.427 ,  748.427 ,  766.427 , ..., 1990.8206, 2050.8206,
#         2071.8206],
#        [ 530.427 ,  716.427 ,  769.427 , ..., 1922.8206, 2019.8206,
#         2071.8206]], dtype=float32), 'image_CH1': array([[ -589.9922  ,   -67.99219 ,    44.007812, ...,   899.1992  ,
#           852.1992  ,   722.1992  ],
#        [ -674.9922  ,  -798.9922  ,  -681.9922  , ...,  1147.1992  ,
#           931.1992  ,   919.1992  ],
#        [-1023.9922  , -1114.9922  , -1185.9922  , ...,  1481.1992  ,
#          1027.1992  ,   993.1992  ],
#        ...,
#        [  706.14844 ,  1054.1484  ,  1226.1484  , ..., 12298.252   ,
#         13671.252   , 13170.252   ],
#        [  945.14844 ,   941.14844 ,   673.14844 , ..., 23106.252   ,
#         24573.252   , 23142.252   ],
#        [  507.14844 ,   734.14844 ,   738.14844 , ..., 33663.25    ,
#         34519.25    , 31867.252   ]], dtype=float32), 'mask': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}, {'animal': 'DK52', 'section': 0, 'index': 26, 'label': 0, 'area': 3, 'row': 1011, 'col': 31257, 'origin': array([14400,     0], dtype=int32), 'height': 1, 'width': 3, 'image_CH3': array([[ 853.63025,  712.63025,  699.63025, ...,  681.9728 ,  599.9728 ,
#          602.9728 ],
#        [ 851.63025,  731.63025,  687.63025, ...,  588.9728 ,  681.9728 ,
#          847.9728 ],
#        [ 948.63025, 1009.63025,  827.63025, ...,  729.9728 ,  608.9728 ,
#          668.9728 ],
#        ...,
#        [1796.2891 , 1797.2891 , 1799.2891 , ..., 1635.4082 , 1731.4082 ,
#         1654.4082 ],
#        [1801.2891 , 1804.2891 , 1804.2891 , ..., 1632.4082 , 1690.4082 ,
#         1483.4082 ],
#        [1551.2891 , 1730.2891 , 1795.2891 , ..., 1594.4082 , 1601.4082 ,
#         1527.4082 ]], dtype=float32), 'image_CH1': array([[ 1.5522910e+03,  1.0362910e+03,  2.8329102e+02, ...,
#          1.3390668e+04,  1.6529668e+04,  2.1357668e+04],
#        [ 6.3229102e+02,  5.7329102e+02, -4.7089844e+00, ...,
#          1.3819668e+04,  1.6181668e+04,  2.0254668e+04],
# ...
#        [False, False, False, ..., False, False, False]])}, {'animal': 'DK52', 'section': 0, 'index': 727, 'label': 0, 'area': 1, 'row': 1775, 'col': 31354, 'origin': array([14400,     0], dtype=int32), 'height': 1, 'width': 1, 'image_CH3': array([[2663.3618 , 2665.3618 , 2657.3618 , ..., 2286.3506 , 2383.3506 ,
#         2407.3506 ],
#        [2447.3618 , 2605.3618 , 2660.3618 , ..., 2252.3506 , 2355.3506 ,
#         2415.3506 ],
#        [2526.3618 , 2651.3618 , 2655.3618 , ..., 2351.3506 , 2424.3506 ,
#         2314.3506 ],
#        ...,
#        [ 853.72144,  696.72144,  783.72144, ...,  880.0659 ,  863.0659 ,
#          807.0659 ],
#        [ 790.72144,  686.72144,  708.72144, ...,  680.0659 ,  681.0659 ,
#          837.0659 ],
#        [ 690.72144,  697.72144,  695.72144, ...,  680.0659 ,  682.0659 ,
#          680.0659 ]], dtype=float32), 'image_CH1': array([[10046.229  ,  9906.229  , 10562.229  , ..., 26925.531  ,
#         28811.531  , 30610.531  ],
#        [10089.229  , 10309.229  , 10033.229  , ..., 26424.531  ,
#         27592.531  , 29719.531  ],
#        [10228.229  , 11024.229  , 11149.229  , ..., 25229.531  ,
#         26564.531  , 28228.531  ],
#        ...,
#        [ 1864.377  ,  1303.377  ,  1179.377  , ...,  1313.6514 ,
#          1578.6514 ,   951.65137],
#        [ 1681.377  ,  1696.377  ,  1031.377  , ...,   994.65137,
#           922.65137,   691.65137],
#        [ 1196.377  ,  1407.377  ,  1526.377  , ...,   514.65137,
#           523.65137,  1063.6514 ]], dtype=float32), 'mask': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}, {'animal': 'DK52', 'section': 0, 'index': 728, 'label': 0, 'area': 1, 'row': 1775, 'col': 31365, 'origin': array([14400,     0], dtype=int32), 'height': 1, 'width': 1, 'image_CH3': array([[2592.871  , 2646.871  , 2652.871  , ..., 2230.9807 , 2353.9807 ,
#         2266.9807 ],
#        [2709.871  , 2648.871  , 2639.871  , ..., 2232.9807 , 2356.9807 ,
#         2426.9807 ],
#        [2918.871  , 2778.871  , 2657.871  , ..., 2267.9807 , 2335.9807 ,
#         2274.9807 ],
#        ...,
#        [ 669.09546,  677.09546,  664.09546, ...,  911.75854,  714.75854,
#          720.75854],
#        [ 682.09546,  627.09546,  683.09546, ...,  773.75854,  695.75854,
#          722.75854],
#        [ 666.09546,  420.09546,  671.09546, ...,  703.75854,  716.75854,
#          927.75854]], dtype=float32), 'image_CH1': array([[10221.235  ,  9517.235  , 10006.235  , ..., 30008.62   ,
#         29452.62   , 28777.62   ],
#        [10750.235  , 10322.235  ,  9960.235  , ..., 28944.62   ,
#         28121.62   , 27132.62   ],
#        [10666.235  , 10749.235  , 10346.235  , ..., 27048.62   ,
#         26030.62   , 24333.62   ],
#        ...,
#        [ 1016.0596 ,  1443.0596 ,   889.0596 , ...,  1558.2266 ,
#          2286.2266 ,  2230.2266 ],
#        [ 1113.0596 ,   925.0596 ,   804.0596 , ...,   986.22656,
#          1959.2266 ,  2047.2266 ],
#        [ 1000.0596 ,   418.05957,   456.05957, ...,   756.22656,
#          1369.2266 ,  1716.2266 ]], dtype=float32), 'mask': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}, {'animal': 'DK52', 'section': 0, 'index': 729, 'label': 0, 'area': 6, 'row': 1775, 'col': 31388, 'origin': array([14400,     0], dtype=int32), 'height': 4, 'width': 3, 'image_CH3': array([[2525.7808 , 2404.7808 , 2493.7808 , ..., 2144.7727 , 2036.7727 ,
#         1938.7727 ],
#        [2437.7808 , 2384.7808 , 2452.7808 , ..., 2245.7727 , 2065.7727 ,
#         1938.7727 ],
#        [2583.7808 , 2453.7808 , 2573.7808 , ..., 2370.7727 , 2313.7727 ,
#         2055.7727 ],
#        ...,
#        [ 659.96814,  677.96814,  934.96814, ...,  966.1443 ,  794.1443 ,
#          950.1443 ],
#        [ 662.96814,  672.96814,  841.96814, ...,  762.1443 ,  727.1443 ,
#          755.1443 ],
#        [ 663.96814,  740.96814,  655.96814, ...,  751.1443 ,  743.1443 ,
#          743.1443 ]], dtype=float32), 'image_CH1': array([[12221.481  , 11584.481  , 11595.481  , ...,  5914.1875 ,
#          6051.1875 ,  5955.1875 ],
#        [11419.481  , 10831.481  , 10745.481  , ...,  5979.1875 ,
#          5916.1875 ,  6110.1875 ],
#        [10187.481  , 10058.481  ,  9918.481  , ...,  6313.1875 ,
#          5837.1875 ,  6017.1875 ],
#        ...,
#        [  943.93555,  1625.9355 ,  1251.9355 , ...,  1552.8369 ,
#          1920.8369 ,  2297.837  ],
#        [  639.93555,  1150.9355 ,  1560.9355 , ...,  1314.8369 ,
#          1864.8369 ,  1706.8369 ],
#        [  538.93555,  1138.9355 ,   916.93555, ...,  1420.8369 ,
#          1754.8369 ,  1887.8369 ]], dtype=float32), 'mask': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}, {'animal': 'DK52', 'section': 0, 'index': 730, 'label': 0, 'area': 5, 'row': 1774, 'col': 31393, 'origin': array([14400,     0], dtype=int32), 'height': 3, 'width': 3, 'image_CH3': array([[2636.7808 , 2642.7808 , 2642.7808 , ..., 1950.7727 , 1949.7727 ,
#         1949.7727 ],
#        [2636.7808 , 2636.7808 , 2636.7808 , ..., 1951.7727 , 1957.7727 ,
#         1949.7727 ],
#        [2646.7808 , 2644.7808 , 2644.7808 , ..., 1949.7727 , 1957.7727 ,
#         1957.7727 ],
#        ...,
#        [ 945.96814,  947.96814,  918.96814, ...,  954.1443 ,  756.1443 ,
#          935.1443 ],
#        [ 792.96814,  783.96814,  779.96814, ...,  735.1443 ,  729.1443 ,
#          742.1443 ],
#        [ 788.96814,  660.96814,  663.96814, ...,  743.1443 ,  743.1443 ,
#          737.1443 ]], dtype=float32), 'image_CH1': array([[12193.481  , 12362.481  , 11707.481  , ...,  5512.1875 ,
#          6129.1875 ,  5951.1875 ],
#        [10811.481  , 11041.481  , 10956.481  , ...,  6024.1875 ,
#          6284.1875 ,  6094.1875 ],
#        [10466.481  ,  9889.481  , 10284.481  , ...,  5861.1875 ,
#          5740.1875 ,  5892.1875 ],
#        ...,
#        [ 2012.9355 ,  1296.9355 ,   886.93555, ...,  1959.8369 ,
#          1323.8369 ,  2064.837  ],
#        [ 1103.9355 ,  1020.93555,   990.93555, ...,  2557.837  ,
#          2126.837  ,  2001.8369 ],
#        [  750.93555,   523.93555,   822.93555, ...,  2336.837  ,
#          1442.8369 ,  1535.8369 ]], dtype=float32), 'mask': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}, {'animal': 'DK52', 'section': 0, 'index': 731, 'label': 0, 'area': 1, 'row': 1774, 'col': 31399, 'origin': array([14400,     0], dtype=int32), 'height': 1, 'width': 1, 'image_CH3': array([[2835.7808 , 2688.9692 , 2642.9692 , ..., 1980.7727 , 2038.7727 ,
#         1970.7727 ],
#        [2664.7808 , 2634.9692 , 2835.9692 , ..., 1959.7727 , 1943.7727 ,
#         1946.7727 ],
#        [2810.7808 , 2895.9692 , 2729.9692 , ..., 1886.7727 , 2083.7727 ,
#         2033.7727 ],
#        ...,
#        [ 938.96814,  929.0625 ,  929.0625 , ...,  733.1443 ,  864.1443 ,
#          737.1443 ],
#        [ 928.96814,  944.0625 ,  926.0625 , ...,  872.1443 ,  874.1443 ,
#          892.1443 ],
#        [ 736.96814,  915.0625 ,  726.0625 , ...,  893.1443 ,  878.1443 ,
#          869.1443 ]], dtype=float32), 'image_CH1': array([[11065.481 , 10362.999 ,  9646.999 , ...,  5631.1875,  5794.1875,
#          5986.1875],
#        [10210.481 , 10774.999 , 10466.999 , ...,  5852.1875,  5533.1875,
#          5843.1875],
#        [10029.481 , 10315.999 , 10453.999 , ...,  5814.1875,  5315.1875,
#          5783.1875],
#        ...,
#        [ 1688.9355,  1105.1289,  1672.1289, ...,  1264.8369,  1722.8369,
#          1913.8369],
#        [ 1324.9355,  1230.1289,  1246.1289, ...,  1494.8369,  1615.8369,
#          1737.8369],
#        [ 1081.9355,   592.1289,  1085.1289, ...,  1797.8369,  1545.8369,
#          1416.8369]], dtype=float32), 'mask': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}, {'animal': 'DK52', 'section': 0, 'index': 732, 'label': 0, 'area': 1, 'row': 1777, 'col': 31369, 'origin': array([14400,     0], dtype=int32), 'height': 1, 'width': 1, 'image_CH3': array([[2563.871  , 2506.871  , 2641.871  , ..., 2276.9807 , 2169.9807 ,
#         2173.9807 ],
#        [2442.871  , 2452.871  , 2495.871  , ..., 2171.9807 , 2175.9807 ,
#         2175.9807 ],
#        [2549.871  , 2588.871  , 2562.871  , ..., 2175.9807 , 2175.9807 ,
#         2175.9807 ],
#        ...,
#        [ 682.09546,  674.09546,  678.09546, ...,  729.75854,  701.75854,
#          705.75854],
#        [ 588.09546,  677.09546,  565.09546, ...,  702.75854,  709.75854,
#          709.75854],
#        [ 510.09546,  667.09546,  534.09546, ...,  709.75854,  709.75854,
#          709.75854]], dtype=float32), 'image_CH1': array([[10106.235  ,  9892.235  ,  9903.235  , ..., 21466.62   ,
#         20273.62   , 18674.62   ],
#        [ 9686.235  ,  9585.235  ,  9695.235  , ..., 19476.62   ,
#         18175.62   , 17010.62   ],
#        [ 9258.235  ,  9725.235  ,  9223.235  , ..., 17779.62   ,
#         16852.62   , 15414.619  ],
#        ...,
#        [ 1346.0596 ,   971.0596 ,   926.0596 , ...,  1417.2266 ,
#          1005.22656,  1042.2266 ],
#        [ 1274.0596 ,   801.0596 ,   466.05957, ...,  1162.2266 ,
#          1043.2266 ,   909.22656],
#        [  761.0596 ,   605.0596 ,   497.05957, ...,  1252.2266 ,
#           945.22656,  1042.2266 ]], dtype=float32), 'mask': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}, {'animal': 'DK52', 'section': 0, 'index': 733, 'label': 0, 'area': 1, 'row': 1776, 'col': 31381, 'origin': array([14400,     0], dtype=int32), 'height': 1, 'width': 1, 'image_CH3': array([[2636.7808 , 2440.7808 , 2541.7808 , ..., 2099.9807 , 2183.9807 ,
#         2215.7727 ],
#        [2640.7808 , 2458.7808 , 2383.7808 , ..., 2152.9807 , 2187.9807 ,
#         2220.7727 ],
#        [2380.7808 , 2532.7808 , 2641.7808 , ..., 2072.9807 , 2078.9807 ,
#         2088.7727 ],
#        ...,
#        [ 902.96814,  915.96814,  681.96814, ...,  965.75854,  806.75854,
#          812.1443 ],
#        [ 690.96814,  697.96814,  884.96814, ...,  806.75854,  706.75854,
#          738.1443 ],
#        [ 676.96814,  660.96814,  683.96814, ...,  703.75854,  708.75854,
#          743.1443 ]], dtype=float32), 'image_CH1': array([[11089.481  , 11002.481  , 10949.481  , ...,  6626.619  ,
#          6225.619  ,  6060.1875 ],
#        [10308.481  , 10325.481  , 10509.481  , ...,  6418.619  ,
#          5852.619  ,  5691.1875 ],
#        [ 9382.481  ,  9599.481  ,  9864.481  , ...,  6094.619  ,
#          5973.619  ,  6054.1875 ],
#        ...,
#        [  730.93555,  1129.9355 ,  1610.9355 , ...,  1398.2266 ,
#          2225.2266 ,  1979.8369 ],
#        [ 1156.9355 ,   899.93555,  1089.9355 , ...,  1853.2266 ,
#          1866.2266 ,  1682.8369 ],
#        [  845.93555,   795.93555,  1338.9355 , ...,  1690.2266 ,
#          1593.2266 ,  1347.8369 ]], dtype=float32), 'mask': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}, {'animal': 'DK52', 'section': 0, 'index': 734, 'label': 0, 'area': 1, 'row': 1779, 'col': 31356, 'origin': array([14400,     0], dtype=int32), 'height': 1, 'width': 1, 'image_CH3': array([[2651.3618 , 2683.3618 , 2663.3618 , ..., 2432.3506 , 2251.3506 ,
#         2275.3506 ],
#        [2674.277  , 2660.277  , 2660.277  , ..., 2425.7307 , 2351.7307 ,
#         2344.7307 ],
#        [2558.277  , 2677.277  , 2664.277  , ..., 2348.7307 , 2319.7307 ,
#         2424.7307 ],
#        ...,
#        [ 444.72144,  679.72144,  692.72144, ...,  686.0659 ,  685.0659 ,
#          678.0659 ],
#        [ 421.72144,  663.72144,  687.72144, ...,  686.0659 ,  686.0659 ,
#          694.0659 ],
#        [ 603.72144,  703.72144,  699.72144, ...,  695.0659 ,  705.0659 ,
#          582.0659 ]], dtype=float32), 'image_CH1': array([[10574.229  , 10808.229  , 10663.229  , ..., 24605.531  ,
#         24582.531  , 24175.531  ],
#        [10716.864  , 10841.864  , 11022.864  , ..., 23073.918  ,
#         22846.918  , 23139.918  ],
#        [10378.864  , 10268.864  , 10674.864  , ..., 20551.918  ,
#         21187.918  , 21014.918  ],
#        ...,
#        [  343.37695,   417.37695,   741.37695, ...,   770.65137,
#           893.65137,  1371.6514 ],
#        [  511.37695,   479.37695,   459.37695, ...,  1010.65137,
#           653.65137,   816.65137],
#        [  604.37695,   700.37695,   653.37695, ...,   840.65137,
#           754.65137,   335.65137]], dtype=float32), 'mask': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}, {'animal': 'DK52', 'section': 0, 'index': 735, 'label': 0, 'area': 1, 'row': 1779, 'col': 31384, 'origin': array([14400,     0], dtype=int32), 'height': 1, 'width': 1, 'image_CH3': array([[2647.7808 , 2647.7808 , 2606.7808 , ..., 2201.7727 , 2102.7727 ,
#         1952.7727 ],
#        [2635.605  , 2650.605  , 2515.605  , ..., 2235.5679 , 2105.5679 ,
#         1934.568  ],
#        [2497.605  , 2652.605  , 2654.605  , ..., 1981.568  , 1971.568  ,
#         1950.568  ],
#        ...,
#        [ 668.96814,  676.96814,  627.96814, ...,  743.1443 ,  738.1443 ,
#          952.1443 ],
#        [ 673.96814,  667.96814,  465.96814, ...,  756.1443 ,  747.1443 ,
#          787.1443 ],
#        [ 615.96814,  677.96814,  669.96814, ...,  527.1443 ,  701.1443 ,
#          589.1443 ]], dtype=float32), 'image_CH1': array([[9293.481  , 9046.481  , 9345.481  , ..., 6009.1875 , 6155.1875 ,
#         6435.1875 ],
#        [9316.116  , 9380.116  , 9054.116  , ..., 6300.6416 , 6067.6416 ,
#         5719.6416 ],
#        [8799.116  , 9168.116  , 8895.116  , ..., 6224.6416 , 5990.6416 ,
#         5932.6416 ],
#        ...,
#        [1498.9355 , 1692.9355 ,  878.93555, ..., 1554.8369 , 1483.8369 ,
#         1208.8369 ],
#        [1259.9355 , 1135.9355 ,  297.93555, ..., 1738.8369 , 1154.8369 ,
#         1175.8369 ],
#        [ 927.93555,  770.93555,  883.93555, ..., 1278.8369 , 1001.8369 ,
#         1065.8369 ]], dtype=float32), 'mask': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}]]

# %%
import sys
# !pip install Path
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting Path
#   Downloading path-16.7.1-py3-none-any.whl (25 kB)
# Installing collected packages: Path
# Successfully installed Path-16.7.1
